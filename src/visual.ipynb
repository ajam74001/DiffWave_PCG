# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
root_dir = '/home/ainazj1/psanjay_ada/users/ainazj1/Datasets/physionet.org/files/circor-heart-sound/1.0.3'
real = pd.read_csv(root_dir+'/real_diffwave_final.csv').drop('Unnamed: 0', axis=1).dropna()
fake = pd.read_csv(root_dir+'/fake_diffwave_final.csv').drop('Unnamed: 0', axis=1).dropna()

# %%
print(real.shape, fake.shape)
# Out:
# (32806, 110) (24427, 110)

# %%
indx = random.randint(0,len(real))
print(indx)
# Out:
# 31868

# %%
plt.plot(real.iloc[indx, :])

# %%
f_indx = random.randint(0,len(fake))
print(f_indx) #21342
# Out:
# 21342

# %%
plt.title('Synthetic Data - DiffWave')
plt.plot(fake.iloc[21342, :])
plt.xticks([0, 20, 40, 60, 80, 100])
# Out:
# ([<matplotlib.axis.XTick at 0x2aaaf24c8100>,
#   <matplotlib.axis.XTick at 0x2aaaf24c80d0>,
#   <matplotlib.axis.XTick at 0x2aaaf24d0af0>,
#   <matplotlib.axis.XTick at 0x2aaaf24b68e0>,
#   <matplotlib.axis.XTick at 0x2aaaf2501df0>,
#   <matplotlib.axis.XTick at 0x2aaaf2501820>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])
